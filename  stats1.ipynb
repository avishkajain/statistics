# %%
#meaures of central tendency is mean,median,mode
age=[28,56,26,35,22,76,89]
#values in list is age
s=(28+56+26+35+22+76+89)/7
s#use brackets because arithmetic uses precedence
# Out:
# 47.42857142857143

# %%
import numpy as np
np.mean(s)#by lirary for bigger datset
# Out:
# np.float64(47.42857142857143)

# %%
#median
nums=[4,4,2,3,7,8]
np.median(nums)
# Out:
# np.float64(4.0)

# %%
#mode
nums=[4,4,2,3,7,8]
np.mode(nums)#numpy has no module mode
#it calculates categorical
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 3
#       1 #mode
#       2 nums=[4,4,2,3,7,8]
# ----> 3 np.mode(nums)#numpy has no module mode
#       4 #it calculates categorical
#
# File ~\AppData\Roaming\Python\Python313\site-packages\numpy\__init__.py:805, in __getattr__(attr)
#     802     import numpy.char as char
#     803     return char.chararray
# --> 805 raise AttributeError(f"module {__name__!r} has no attribute {attr!r}")
#
# AttributeError: module 'numpy' has no attribute 'mode'

# %%
from scipy import stats
stats.mode(nums)
# Out:
# ModeResult(mode=np.int64(4), count=np.int64(2))

# %%
import statistics
statistics.mode(nums)
# Out:
# 4

# %%
#mean is affected by outliers and median is not
